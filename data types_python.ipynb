# %% [markdown]
# # data types in python
# 1. python have 3 data types
# 2. int(integer)
# 3. str(string)
# 4. float(decimal)

# %%
name="shivaji123"
age= 25
salary=10000.25
print(name)
print(age)
print(salary)

# %%
data="120"
print(data)
print(type(data))
# Out:
# 120
# <class 'str'>

# %%
a=100
b=120
print(a+b)
# Out:
# 220

# %%
v1=100
v2=100.25
print(v1+v2)
# Out:
# 200.25
